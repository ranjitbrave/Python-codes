# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\ranji\04_22_Instacart_Basket_Analysis'

# %%
df_prod = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_prod.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prod[df_prod['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods_clean = df_prod[df_prod['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# # Tasks

# %%
#2 the maximum value for prices seems to be unrealistic
df_prod.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
#3 Checking for mixed data types. 
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
   print (col)

# %%
#4 No mixed data types found as nothing is printed?

# %%
#5 Checking for missing values
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# order_dow                      0
# order_hour                     0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# Missing data only found in days since prior order but this is ok if orders are placed consecutively

# %%
#6 No next step to be taken as the missing values can be kept?

# %%
#7 Checking for duplicate values - No duplicates found
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, order_dow, order_hour, days_since_prior_order]
# Index: []

# %%
#Exporting Data frames
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders.csv'))

# %%
df_prods_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products.csv'))

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour  \
# 0                 0   2539329        1             1          2           8
# 1                 1   2398795        1             2          3           7
# 2                 2    473747        1             3          3          12
# 3                 3   2254736        1             4          4           7
# 4                 4    431534        1             5          4          15
# ...             ...       ...      ...           ...        ...         ...
# 3421078     3421078   2266710   206209            10          5          18
# 3421079     3421079   1854736   206209            11          4          10
# 3421080     3421080    626363   206209            12          1          12
# 3421081     3421081   2977660   206209            13          1          12
# 3421082     3421082    272231   206209            14          6          14
#
#          days_since_prior_order
# ...

# %%
df_ords.drop_duplicates()
# Out:
#          Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour  \
# 0                 0   2539329        1             1          2           8
# 1                 1   2398795        1             2          3           7
# 2                 2    473747        1             3          3          12
# 3                 3   2254736        1             4          4           7
# 4                 4    431534        1             5          4          15
# ...             ...       ...      ...           ...        ...         ...
# 3421078     3421078   2266710   206209            10          5          18
# 3421079     3421079   1854736   206209            11          4          10
# 3421080     3421080    626363   206209            12          1          12
# 3421081     3421081   2977660   206209            13          1          12
# 3421082     3421082    272231   206209            14          6          14
#
#          days_since_prior_order
# ...
