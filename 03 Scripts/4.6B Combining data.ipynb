# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\ranji\04_22_Instacart_Basket_Analysis'

# %%
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
#Importing products data frame
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
#Checking common key to merge
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  order_dow  \
# 0           0             0   2539329        1             1          2
# 1           0             0   2539329        1             1          2
# 2           0             0   2539329        1             1          2
# 3           0             0   2539329        1             1          2
# 4           0             0   2539329        1             1          2
#
#    order_hour  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
#Merging on product_id
orders_products_merged = orders_products_combined.merge(df_prods, on = 'product_id', indicator = 'True')

# %%
orders_products_merged.in

# %%
#Checking merge
orders_products_merged.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  order_dow  \
# 0           0             0   2539329        1             1          2
# 1           1             1   2398795        1             2          3
# 2           2             2    473747        1             3          3
# 3           3             3   2254736        1             4          4
# 4           4             4    431534        1             5          4
#
#    order_hour  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           7                    15.0         196                  1
# 2          12                    21.0         196                  1
# 3           7                    29.0         196                  1
# 4          15                    28.0         196                  1
#
#    reordered _merge product_name  aisle_id  department_id  prices  True
# 0          0   both         Soda        77              7     9.0  both
# 1          1   both         Soda        77              7     9.0  both
# 2          1   both         Soda        77              7     9.0  both
# 3          1   both         Soda        77              7     9.0  both
# 4          1   both         Soda        77              7     9.0  both

# %%
#Exporting new file
orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
